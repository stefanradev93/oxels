# %%
import sys
sys.path.append("../")

import torch

from oxels import SwinUNet

# %%
x = torch.randn((32, 3, 128, 128))

# %%
unet = SwinUNet(height=128, width=128, channels=3, patch_embed_dim=32, patch_size=4, num_stages=3, oxel_dim=8)

# %%
unet(x).shape
# Out:
# torch.Size([32, 8, 128, 128])
