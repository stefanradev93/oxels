# %%
import sys 
import numpy as np
import matplotlib.pyplot as plt
import cv2
import glob

from torch.utils.data import DataLoader

sys.path.append("../")

from oxels.transforms import PerspectiveTransform
from oxels.datasets import PerspectiveDataset
from oxels.losses import original_loss
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 13
#      11 from oxels.transforms import PerspectiveTransform
#      12 from oxels.datasets import PerspectiveDataset
# ---> 13 from oxels.losses import original_loss
#
# File ~/oxels/notebooks/../oxels/losses/__init__.py:1
# ----> 1 from .original_loss import original_loss
#
# ImportError: cannot import name 'original_loss' from 'oxels.losses.original_loss' (/home/space/oxels/notebooks/../oxels/losses/original_loss.py)

# %%
files = glob.glob("../../schenectadata/image-matching-challenge-2022/train/*/images/*.jpg")

# %%
len(files)
# Out:
# 5678

# %%
files = glob.glob("../../Pictures/Screenshots/*.png")
dataset = PerspectiveImagesDataset(files, lambda x: x, 256+128, 256, 0.5)

# %%
loader = DataLoader(
    dataset,
    batch_size=4,      # whatever batch size you want
    num_workers=1,      # parallel data loading
    pin_memory=True,    # if you’re on CUDA
)

# %%
view1, view2, permutation, flags, mask1, mask2 = next(iter(loader))
plt.imshow(view1[0].detach().numpy().transpose((1,2,0)))

# %%
original_loss_func(view1, view2, permutation, flags, mask1, mask2)
# Out:
# tensor(0.1434)
